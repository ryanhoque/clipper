# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [3.136, 4.096, 16.384, 65.536, 262.144, 1048.576]
a = [a/1000 for a in [9.25, 13.99, 35.24, 119.93, 461.07, 1846.3]]
b = [a/1000 for a in [15.19, 195.58, 486.99, 1692.47, 6507.87, 4347.47]]
c = [a/1000 for a in [37.13, 226.39, 619.94, 2218.07, 8634.67, 8657.9]]
d = [a/1000 for a in [84.6, 292.42, 887.07, 3290.84, 13107.75, 22087.22]]
e = [a/1000 for a in [181.91, 422.97, 1436.34, 5461.35, 24632.81, 39613.25]]
plt.style.use('fivethirtyeight')
fig = plt.figure()
fig.set_size_inches(12,8.4)
plt.plot(x, a)
plt.plot(x, b)
plt.plot(x, c)
plt.plot(x, d)
plt.plot(x, e)
plt.xlabel("Image Size (KB)")
plt.ylabel("Average Parse Latency (ms)")
plt.title("Clipper REST API Profiling Results, split by Batch Size")
plt.legend(("1", "4", "8", "16", "32"))
